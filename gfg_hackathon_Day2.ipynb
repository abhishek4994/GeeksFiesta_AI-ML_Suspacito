# %%
import pandas as pd
import numpy as np
data=pd.read_csv('updated_data.csv')

# %%
data
# Out:
#        Unnamed: 0  year  month   day  hour  PM2.5  temperature  pressure  \
# 0               2  2013    3.0   1.0   2.0    7.0         -1.1    1023.5
# 1               3  2013    3.0   1.0   3.0    6.0         -1.4    1024.5
# 2               4  2013    3.0   1.0   4.0    3.0         -2.0    1025.2
# 3               6  2013    3.0   1.0   6.0    3.0         -2.6    1026.5
# 4               7  2013    3.0   1.0   7.0    3.0         -1.6    1027.4
# ...           ...   ...    ...   ...   ...    ...          ...       ...
# 31359       35022  2017    2.0  27.0   6.0   80.0         -0.3    1019.4
# 31360       35032  2017    2.0  27.0  16.0   75.0         15.9    1014.0
# 31361       35035  2017    2.0  27.0  19.0   51.0         11.5    1014.1
# 31362       35042  2017    2.0  28.0   2.0    9.0          8.6    1016.0
# 31363       35054  2017    2.0  28.0  14.0    5.0         14.6    1013.3
#
#        rain wind_direction  wind_speed
# 0       0.0            NNW         5.6
# ...

# %% [markdown]
# Dropping the unnecessary 'Unnamed: 0' column

# %%
data.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %% [markdown]
# Importing libraries used for data visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# Finding correlations between the columns present:-

# %%
plot=plt.scatter( data["month"],data["year"])

# %% [markdown]
# We have data of only 2 months for 2017 and only 10 months for 2013

# %%
plot=plt.scatter( data["temperature"],data["pressure"])

# %% [markdown]
# Temp decreases with increase in pressure

# %%
plot=plt.scatter( data["temperature"],data["month"])

# %% [markdown]
# Temp is maximum at month 6-8

# %%
plot=plt.scatter( data["temperature"],data["rain"])

# %% [markdown]
# Rain is maximum at temp ~ 20

# %%
plot=plt.scatter( data["pressure"],data["rain"])

# %% [markdown]
# Rain is maximum at pressure~1000

# %%
plot=plt.scatter( data["rain"],data["month"])

# %% [markdown]
# Rain is maximum at month 6-9

# %%
plot=plt.scatter( data["rain"],data["wind_speed"])

# %% [markdown]
# Rain is more when the wind speed is lesser

# %%
plot=plt.scatter( data["temperature"],data["PM2.5"])

# %% [markdown]
# Presence of PM2.5 increases as temperature increases up till a certain maximum and then decreases (with a less steep slope) with further increase in pressure

# %%
plot=plt.scatter( data["pressure"],data["PM2.5"])

# %% [markdown]
# Presence of PM2.5 increases as pressure increases up till a certain maximum and then decreases with further increase in pressure

# %%
plot=plt.scatter( data["rain"],data["PM2.5"])

# %% [markdown]
# Presence of PM2.5 is the highest when rain is low

# %%
plot=plt.scatter(data["wind_speed"],data["PM2.5"])

# %% [markdown]
# Presence of PM2.5 is lesser as wind speed increases

# %% [markdown]
# Finding the correlation of PM2.5 with rest of the columns using correlation matrix:

# %%
import seaborn as sb

# %%
#Columns shown here are selected by corr() since they are ideal for the plot
print(data.corr())
# Out:
#                  year     month       day      hour     PM2.5  temperature  \
# year         1.000000 -0.197662 -0.005173  0.001179 -0.060396    -0.054424
# month       -0.197662  1.000000 -0.008420 -0.000381  0.020311     0.147472
# day         -0.005173 -0.008420  1.000000 -0.000147  0.022787     0.034759
# hour         0.001179 -0.000381 -0.000147  1.000000 -0.011330     0.143663
# PM2.5       -0.060396  0.020311  0.022787 -0.011330  1.000000    -0.121076
# temperature -0.054424  0.147472  0.034759  0.143663 -0.121076     1.000000
# pressure     0.154791 -0.011314 -0.003206 -0.038655 -0.004536    -0.820624
# rain         0.005327  0.014014 -0.000903  0.011477 -0.012703     0.033473
# wind_speed   0.149674 -0.161720 -0.025752  0.160414 -0.268476     0.039042
#
#              pressure      rain  wind_speed
# year         0.154791  0.005327    0.149674
# month       -0.011314  0.014014   -0.161720
# day         -0.003206 -0.000903   -0.025752
# ...

# %%
#Visualizing the correlation matrix using heatmap
dataplot = sb.heatmap(data.corr(), cmap="YlGnBu", annot=True ,cbar=True,linewidths=3)
plt.show()

# %% [markdown]
# Plotting box plot for every column and finding observations:

# %%
plt.boxplot(data['year'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e164c1b7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e164c1beb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e164c1b490>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e164c285e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e164c28940>],
#  'means': []}

# %% [markdown]
# 2017 is an outlier here as its frequency is low

# %%
plt.boxplot(data['month'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e164c74d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e164c83430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e164c749a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e164c83af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e164c83e50>],
#  'means': []}

# %% [markdown]
# month 6 is the median

# %%
plt.boxplot(data['day'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e164cd24c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e164cd2b80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e164cd2160>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e164ce02b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e164ce0610>],
#  'means': []}

# %% [markdown]
# day 15 is the median

# %%
plt.boxplot(data['hour'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e164d35100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e164d357c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e164d23d60>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e164d35e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e164d3f220>],
#  'means': []}

# %% [markdown]
# hour~12 is the median

# %%
plt.boxplot(data['PM2.5'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e164d89490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e164d89b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e164d89130>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e164d93220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e164d93550>],
#  'means': []}

# %% [markdown]
# There are many instances of PM2.5 outside of the IQR , where the median is around 75

# %%
plt.boxplot(data['temperature'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e164dda730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e164ddadf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e164dda3d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e164de5520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e164de5880>],
#  'means': []}

# %% [markdown]
# temp~16 is median

# %%
plt.boxplot(data['pressure'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e164e29e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e164e39550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e164e29af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e164e39c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e164e39fa0>],
#  'means': []}

# %% [markdown]
# Pressure= 1010 is the median

# %%
plt.boxplot(data['rain'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e164e8b670>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e164e8bcd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e164e8b310>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e164e973d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e164e97730>],
#  'means': []}

# %% [markdown]
# There are many instances of rain outside of the IQR , where the median is 0

# %%
plt.boxplot(data['wind_speed'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e1401c69a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2e1401c6640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2e1401c6370>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e1414cf4f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e1414cf220>],
#  'means': []}

# %% [markdown]
# There are many instances of wind speed outside of the IQR , where the median is windspeed ~ 1.4
